# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d
plt.rcParams['figure.dpi'] = 600

# %%
a = np.genfromtxt('RRUFF_Hematite_R060190_Eng.txt',delimiter=', ')
r = a[:-75,0]
i = a[:-75,1]
g = gaussian_filter1d(i,sigma=50)
isub = i-g
y = gaussian_filter1d(isub,sigma=2)
di = np.gradient(i)
yy = gaussian_filter1d(-np.gradient(di),sigma=2)

# %%
frame2 = plt.gca()
plt.plot(r,yy,c='Black',linewidth=1) 
plt.xlim(180,1200)
frame2.axes.get_yaxis().set_ticks([])
plt.xlabel('Raman Shift (cm-1)')
plt.ylabel('Inverse 2nd Gradient of Intensity \n(Gaussian Filtered $\\sigma$=2)')
plt.title('RRUFF Hematite 2nd Gradient of Raman Spectrum')
plt.savefig('Hematite_2G.png')
