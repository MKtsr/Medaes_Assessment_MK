# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d

# %%
t2019a = np.genfromtxt('T2019.06.10a_260319_MAP_Average.txt',delimiter='\t')
r = t2019a[:-50,0]
i = t2019a[:-50,1]
di = np.gradient(i)
y = gaussian_filter1d(-np.gradient(di),sigma=2)

# %%
plt.plot(r,y,c=cc,linewidth=1) 
plt.xlim(np.min(r),np.max(r))
plt.xlabel('Raman Shift (cm-1)')
plt.ylabel('2nd Derivative Intensity Gradient (Gaussian Filtered')
# Out:
# Text(0, 0.5, '2nd Derivative Intensity Gradient (Gaussian Filtered')
