# %%
# Import packages and set plot parameters
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
plt.rcParams['figure.dpi'] = 150

# %%
m = np.genfromtxt('Data/B0959.3c_Map_260304.txt',delimiter='\t')
x = m[:,0]
y = m[:,1]
r = m[:,2]
i = m[:,3]
