# %%
# Import packages and set plot parameters
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import ramanspy
# plt.rcParams['figure.dpi'] = 600

# %%
# Import data and define variables
raman_data = ramanspy.load.renishaw('Data/B0959.3c_map_260304.wdf')
